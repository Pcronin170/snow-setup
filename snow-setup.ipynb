# %% [markdown]
# # snow-setup
# This notebook will contain the scratch work to connect snowflake and Jupyter lab

# %% [markdown]
# # Install Packages
# Install necessary packages to make the connection following the [Connecting Jupyter Notebook with Snowflake](https://snowflakecommunity.force.com/s/article/Connecting-Jupyter-Notebook-with-Snowflake) guide.

# %%
#!/usr/bin/env python
import snowflake.connector
import pandas as pd
from sqlalchemy.engine import create_engine
from snowflake.sqlalchemy import URL

# %%
# Create Snowflake URL
engine = create_engine(URL(
    account = 'azntdro-rxb32482',
    user = 'pcronin',
    password = '1!VioletSnowflake1!',
    database = 'ANALYTICS',
    schema = 'TEST',
    warehouse = 'TEST_XS',
    role='ANALYTICS',
))

connection = engine.connect()
# %reload_ext sql
# %sql {engine.url}

# %% [markdown]
# # Hist

# %%
# %%sql
#
# SELECT *
#   FROM SNOWFLAKE_SAMPLE_DATA.TPCH_SF1.CUSTOMER
#  LIMIT 50
# Out:
#  * snowflake://pcronin:***@azntdro-rxb32482/ANALYTICS/TEST?role=ANALYTICS&warehouse=TEST_XS
# 50 rows affected.
# [(60001, 'Customer#000060001', '9Ii4zQn9cX', 14, '24-678-784-9652', Decimal('9957.56'), 'HOUSEHOLD', 'l theodolites boost slyly at the platelets: permanently ironic packages wake slyly pend'),
#  (60002, 'Customer#000060002', 'ThGBMjDwKzkoOxhz', 15, '25-782-500-8435', Decimal('742.46'), 'BUILDING', ' beans. fluffily regular packages'),
#  (60003, 'Customer#000060003', 'Ed hbPtTXMTAsgGhCr4HuTzK,Md2', 16, '26-859-847-7640', Decimal('2526.92'), 'BUILDING', 'fully pending deposits sleep quickly. blithely unusual accounts across the blithely bold requests are quickly'),
#  (60004, 'Customer#000060004', 'NivCT2RVaavl,yUnKwBjDyMvB42WayXCnky', 10, '20-573-674-7999', Decimal('7975.22'), 'AUTOMOBILE', ' furiously above the ironic packages. slyly brave ideas boost. final platelets detect according to the ironi'),
# ...

# %%
customer_df
# Out:
# [(60001, 'Customer#000060001', '9Ii4zQn9cX', 14, '24-678-784-9652', Decimal('9957.56'), 'HOUSEHOLD', 'l theodolites boost slyly at the platelets: permanently ironic packages wake slyly pend'),
#  (60002, 'Customer#000060002', 'ThGBMjDwKzkoOxhz', 15, '25-782-500-8435', Decimal('742.46'), 'BUILDING', ' beans. fluffily regular packages'),
#  (60003, 'Customer#000060003', 'Ed hbPtTXMTAsgGhCr4HuTzK,Md2', 16, '26-859-847-7640', Decimal('2526.92'), 'BUILDING', 'fully pending deposits sleep quickly. blithely unusual accounts across the blithely bold requests are quickly'),
#  (60004, 'Customer#000060004', 'NivCT2RVaavl,yUnKwBjDyMvB42WayXCnky', 10, '20-573-674-7999', Decimal('7975.22'), 'AUTOMOBILE', ' furiously above the ironic packages. slyly brave ideas boost. final platelets detect according to the ironi'),
# ...
